in <module>
#       file_stream = BytesIO(request.urlopen(url, context=context).read())
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 214, in urlopen
#       return opener.open(url, data, timeout)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 517, in open
#       response = self._open(req, data)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 534, in _open
#       result = self._call_chain(self.handle_open, protocol, protocol +
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 494, in _call_chain
#       result = func(*args)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1385, in https_open
#       return self.do_open(http.client.HTTPSConnection, req,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1345, in do_open
#       raise URLError(err)
#   urllib.error.URLError: <urlopen error EOF occurred in violation of protocol (_ssl.c:1122)>
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/98/cb/f77d9bd5f64246074af364cc30e20e3044c533890f3b67d30e89615c2fc5/ibm_db-3.0.1.tar.gz#sha256=a609e07295d16455d40df94ddd61b3d476606f5d44e3352103776e3ecbff185a (from https://pypi.org/simple/ibm-db/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Tom\AppData\Local\Programs\Python\Python39\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Tom\\AppData\\Local\\Temp\\pip-install-u_hut4gs\\ibm-db_cb51f9f65b0b4c768472cca840d64237\\setup.py'"'"'; __file__='"'"'C:\\Users\\Tom\\AppData\\Local\\Temp\\pip-install-u_hut4gs\\ibm-db_cb51f9f65b0b4c768472cca840d64237\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Tom\AppData\Local\Temp\pip-pip-egg-info-68wjmvm3'
#        cwd: C:\Users\Tom\AppData\Local\Temp\pip-install-u_hut4gs\ibm-db_cb51f9f65b0b4c768472cca840d64237\
#   Complete output (44 lines):
#   Detected 64-bit Python
#   Downloading https://public.dhe.ibm.com/ibmdl/export/pub/software/data/db2/drivers/odbc_cli/ntx64_odbc_cli.zip
#   Traceback (most recent call last):
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1342, in do_open
#       h.request(req.get_method(), req.selector, req.data, headers,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1255, in request
#       self._send_request(method, url, body, headers, encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1301, in _send_request
#       self.endheaders(body, encode_chunked=encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1250, in endheaders
#       self._send_output(message_body, encode_chunked=encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1010, in _send_output
#       self.send(msg)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 950, in send
#       self.connect()
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1424, in connect
#       self.sock = self._context.wrap_socket(self.sock,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 500, in wrap_socket
#       return self.sslsocket_class._create(
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 1040, in _create
#       self.do_handshake()
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 1309, in do_handshake
#       self._sslobj.do_handshake()
#   ssl.SSLEOFError: EOF occurred in violation of protocol (_ssl.c:1122)
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\Tom\AppData\Local\Temp\pip-install-u_hut4gs\ibm-db_cb51f9f65b0b4c768472cca840d64237\setup.py", line 184, in <module>
#       file_stream = BytesIO(request.urlopen(url, context=context).read())
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 214, in urlopen
#       return opener.open(url, data, timeout)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 517, in open
#       response = self._open(req, data)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 534, in _open
#       result = self._call_chain(self.handle_open, protocol, protocol +
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 494, in _call_chain
#       result = func(*args)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1385, in https_open
#       return self.do_open(http.client.HTTPSConnection, req,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1345, in do_open
#       raise URLError(err)
#   urllib.error.URLError: <urlopen error EOF occurred in violation of protocol (_ssl.c:1122)>
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/8a/98/35f57832038047870eb6f9ce75f46992197e6e8eb99ad5b61105a0bf0b30/ibm_db-3.0.0.tar.gz#sha256=ad6102a359a88654d9829345ccecb269b545bc03a961ce8f415c5dced350254c (from https://pypi.org/simple/ibm-db/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Tom\AppData\Local\Programs\Python\Python39\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Tom\\AppData\\Local\\Temp\\pip-install-u_hut4gs\\ibm-db_eb74fc822aee48a18abb955936a637f1\\setup.py'"'"'; __file__='"'"'C:\\Users\\Tom\\AppData\\Local\\Temp\\pip-install-u_hut4gs\\ibm-db_eb74fc822aee48a18abb955936a637f1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Tom\AppData\Local\Temp\pip-pip-egg-info-v8f8bsbl'
#        cwd: C:\Users\Tom\AppData\Local\Temp\pip-install-u_hut4gs\ibm-db_eb74fc822aee48a18abb955936a637f1\
#   Complete output (44 lines):
#   Detected 64-bit Python
#   Downloading https://public.dhe.ibm.com/ibmdl/export/pub/software/data/db2/drivers/odbc_cli/ntx64_odbc_cli.zip
#   Traceback (most recent call last):
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1342, in do_open
#       h.request(req.get_method(), req.selector, req.data, headers,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1255, in request
#       self._send_request(method, url, body, headers, encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1301, in _send_request
#       self.endheaders(body, encode_chunked=encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1250, in endheaders
#       self._send_output(message_body, encode_chunked=encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1010, in _send_output
#       self.send(msg)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 950, in send
#       self.connect()
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1424, in connect
#       self.sock = self._context.wrap_socket(self.sock,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 500, in wrap_socket
#       return self.sslsocket_class._create(
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 1040, in _create
#       self.do_handshake()
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 1309, in do_handshake
#       self._sslobj.do_handshake()
#   ssl.SSLEOFError: EOF occurred in violation of protocol (_ssl.c:1122)
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\Tom\AppData\Local\Temp\pip-install-u_hut4gs\ibm-db_eb74fc822aee48a18abb955936a637f1\setup.py", line 164, in <module>
#       file_stream = BytesIO(request.urlopen(url).read())
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 214, in urlopen
#       return opener.open(url, data, timeout)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 517, in open
#       response = self._open(req, data)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 534, in _open
#       result = self._call_chain(self.handle_open, protocol, protocol +
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 494, in _call_chain
#       result = func(*args)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1385, in https_open
#       return self.do_open(http.client.HTTPSConnection, req,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1345, in do_open
#       raise URLError(err)
#   urllib.error.URLError: <urlopen error EOF occurred in violation of protocol (_ssl.c:1122)>
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3f/61/389c6decacfed61c2724005b8c2be61f2c699f731b53af13517e5a0e6e98/ibm_db-2.0.9.tar.gz#sha256=72a5b1911125311bfa53dab40cf6684965abf4a548181f4af53dbe7d527f68c6 (from https://pypi.org/simple/ibm-db/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Tom\AppData\Local\Programs\Python\Python39\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Tom\\AppData\\Local\\Temp\\pip-install-u_hut4gs\\ibm-db_1c87abe9d6564587ab875f36d8c14dca\\setup.py'"'"'; __file__='"'"'C:\\Users\\Tom\\AppData\\Local\\Temp\\pip-install-u_hut4gs\\ibm-db_1c87abe9d6564587ab875f36d8c14dca\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Tom\AppData\Local\Temp\pip-pip-egg-info-hgg95vwt'
#        cwd: C:\Users\Tom\AppData\Local\Temp\pip-install-u_hut4gs\ibm-db_1c87abe9d6564587ab875f36d8c14dca\
#   Complete output (44 lines):
#   Detected 64-bit Python
#   Downloading https://public.dhe.ibm.com/ibmdl/export/pub/software/data/db2/drivers/odbc_cli/ntx64_odbc_cli.zip
#   Traceback (most recent call last):
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1342, in do_open
#       h.request(req.get_method(), req.selector, req.data, headers,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1255, in request
#       self._send_request(method, url, body, headers, encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1301, in _send_request
#       self.endheaders(body, encode_chunked=encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1250, in endheaders
#       self._send_output(message_body, encode_chunked=encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1010, in _send_output
#       self.send(msg)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 950, in send
#       self.connect()
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1424, in connect
#       self.sock = self._context.wrap_socket(self.sock,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 500, in wrap_socket
#       return self.sslsocket_class._create(
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 1040, in _create
#       self.do_handshake()
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 1309, in do_handshake
#       self._sslobj.do_handshake()
#   ssl.SSLEOFError: EOF occurred in violation of protocol (_ssl.c:1122)
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\Tom\AppData\Local\Temp\pip-install-u_hut4gs\ibm-db_1c87abe9d6564587ab875f36d8c14dca\setup.py", line 170, in <module>
#       file_stream = BytesIO(request.urlopen(url).read())
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 214, in urlopen
#       return opener.open(url, data, timeout)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 517, in open
#       response = self._open(req, data)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 534, in _open
#       result = self._call_chain(self.handle_open, protocol, protocol +
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 494, in _call_chain
#       result = func(*args)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1385, in https_open
#       return self.do_open(http.client.HTTPSConnection, req,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1345, in do_open
#       raise URLError(err)
#   urllib.error.URLError: <urlopen error EOF occurred in violation of protocol (_ssl.c:1122)>
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/f8/6f/5f8186cb31021409235a948be5e29d77761ef92747a101360003747c4105/ibm_db-2.0.8.tar.gz#sha256=5a12e1e5c2421294dfcb28e023c602fe89d3f02a97b9959edfe927aafb40c3a3 (from https://pypi.org/simple/ibm-db/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Tom\AppData\Local\Programs\Python\Python39\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Tom\\AppData\\Local\\Temp\\pip-install-u_hut4gs\\ibm-db_dc64264c53cb43f786f015139847b64b\\setup.py'"'"'; __file__='"'"'C:\\Users\\Tom\\AppData\\Local\\Temp\\pip-install-u_hut4gs\\ibm-db_dc64264c53cb43f786f015139847b64b\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Tom\AppData\Local\Temp\pip-pip-egg-info-tp6eoeop'
#        cwd: C:\Users\Tom\AppData\Local\Temp\pip-install-u_hut4gs\ibm-db_dc64264c53cb43f786f015139847b64b\
#   Complete output (44 lines):
#   Detected 64-bit Python
#   Downloading https://public.dhe.ibm.com/ibmdl/export/pub/software/data/db2/drivers/odbc_cli/ntx64_odbc_cli.zip
#   Traceback (most recent call last):
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1342, in do_open
#       h.request(req.get_method(), req.selector, req.data, headers,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1255, in request
#       self._send_request(method, url, body, headers, encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1301, in _send_request
#       self.endheaders(body, encode_chunked=encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1250, in endheaders
#       self._send_output(message_body, encode_chunked=encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1010, in _send_output
#       self.send(msg)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 950, in send
#       self.connect()
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1424, in connect
#       self.sock = self._context.wrap_socket(self.sock,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 500, in wrap_socket
#       return self.sslsocket_class._create(
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 1040, in _create
#       self.do_handshake()
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 1309, in do_handshake
#       self._sslobj.do_handshake()
#   ssl.SSLEOFError: EOF occurred in violation of protocol (_ssl.c:1122)
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\Tom\AppData\Local\Temp\pip-install-u_hut4gs\ibm-db_dc64264c53cb43f786f015139847b64b\setup.py", line 159, in <module>
#       file_stream = BytesIO(request.urlopen(url).read())
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 214, in urlopen
#       return opener.open(url, data, timeout)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 517, in open
#       response = self._open(req, data)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 534, in _open
#       result = self._call_chain(self.handle_open, protocol, protocol +
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 494, in _call_chain
#       result = func(*args)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1385, in https_open
#       return self.do_open(http.client.HTTPSConnection, req,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1345, in do_open
#       raise URLError(err)
#   urllib.error.URLError: <urlopen error EOF occurred in violation of protocol (_ssl.c:1122)>
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/54/8a/54857a841cbd485d68f9852dfc16d27b069987a65ade38bb9288471ae98b/ibm_db-2.0.7.tar.gz#sha256=3db1dab4f5ea2efa37b3e8cdda0f19e60a37c716f56a12455dd40e8dad56e64f (from https://pypi.org/simple/ibm-db/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Tom\AppData\Local\Programs\Python\Python39\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Tom\\AppData\\Local\\Temp\\pip-install-u_hut4gs\\ibm-db_66ee786644c4488a92000a2e37261c76\\setup.py'"'"'; __file__='"'"'C:\\Users\\Tom\\AppData\\Local\\Temp\\pip-install-u_hut4gs\\ibm-db_66ee786644c4488a92000a2e37261c76\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Tom\AppData\Local\Temp\pip-pip-egg-info-7_lxdc8k'
#        cwd: C:\Users\Tom\AppData\Local\Temp\pip-install-u_hut4gs\ibm-db_66ee786644c4488a92000a2e37261c76\
#   Complete output (44 lines):
#   Detected 64-bit Python
#   Downloading https://public.dhe.ibm.com/ibmdl/export/pub/software/data/db2/drivers/odbc_cli/ntx64_odbc_cli.zip
#   Traceback (most recent call last):
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1342, in do_open
#       h.request(req.get_method(), req.selector, req.data, headers,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1255, in request
#       self._send_request(method, url, body, headers, encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1301, in _send_request
#       self.endheaders(body, encode_chunked=encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1250, in endheaders
#       self._send_output(message_body, encode_chunked=encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1010, in _send_output
#       self.send(msg)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 950, in send
#       self.connect()
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1424, in connect
#       self.sock = self._context.wrap_socket(self.sock,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 500, in wrap_socket
#       return self.sslsocket_class._create(
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 1040, in _create
#       self.do_handshake()
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 1309, in do_handshake
#       self._sslobj.do_handshake()
#   ssl.SSLEOFError: EOF occurred in violation of protocol (_ssl.c:1122)
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\Tom\AppData\Local\Temp\pip-install-u_hut4gs\ibm-db_66ee786644c4488a92000a2e37261c76\setup.py", line 159, in <module>
#       file_stream = BytesIO(request.urlopen(url).read())
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 214, in urlopen
#       return opener.open(url, data, timeout)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 517, in open
#       response = self._open(req, data)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 534, in _open
#       result = self._call_chain(self.handle_open, protocol, protocol +
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 494, in _call_chain
#       result = func(*args)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1385, in https_open
#       return self.do_open(http.client.HTTPSConnection, req,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1345, in do_open
#       raise URLError(err)
#   urllib.error.URLError: <urlopen error EOF occurred in violation of protocol (_ssl.c:1122)>
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/b6/0c/a8d57078772abcc876f6a2be2252f12284aa6f71f41d3c2910f23369d7d2/ibm_db-2.0.6.1.tar.gz#sha256=bdc6543702e19d8ff7a0ddef715a9ee32a7753686cbcfe99095c2e357efe4135 (from https://pypi.org/simple/ibm-db/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Tom\AppData\Local\Programs\Python\Python39\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Tom\\AppData\\Local\\Temp\\pip-install-u_hut4gs\\ibm-db_3bb038a8cd364da5be970811a552b120\\setup.py'"'"'; __file__='"'"'C:\\Users\\Tom\\AppData\\Local\\Temp\\pip-install-u_hut4gs\\ibm-db_3bb038a8cd364da5be970811a552b120\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Tom\AppData\Local\Temp\pip-pip-egg-info-3wixdhnh'
#        cwd: C:\Users\Tom\AppData\Local\Temp\pip-install-u_hut4gs\ibm-db_3bb038a8cd364da5be970811a552b120\
#   Complete output (44 lines):
#   Detected 64-bit Python
#   Downloading https://public.dhe.ibm.com/ibmdl/export/pub/software/data/db2/drivers/odbc_cli/ntx64_odbc_cli.zip
#   Traceback (most recent call last):
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1342, in do_open
#       h.request(req.get_method(), req.selector, req.data, headers,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1255, in request
#       self._send_request(method, url, body, headers, encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1301, in _send_request
#       self.endheaders(body, encode_chunked=encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1250, in endheaders
#       self._send_output(message_body, encode_chunked=encode_chunked)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1010, in _send_output
#       self.send(msg)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 950, in send
#       self.connect()
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1424, in connect
#       self.sock = self._context.wrap_socket(self.sock,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 500, in wrap_socket
#       return self.sslsocket_class._create(
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 1040, in _create
#       self.do_handshake()
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 1309, in do_handshake
#       self._sslobj.do_handshake()
#   ssl.SSLEOFError: EOF occurred in violation of protocol (_ssl.c:1122)
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\Tom\AppData\Local\Temp\pip-install-u_hut4gs\ibm-db_3bb038a8cd364da5be970811a552b120\setup.py", line 154, in <module>
#       file_stream = BytesIO(request.urlopen(url).read())
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 214, in urlopen
#       return opener.open(url, data, timeout)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 517, in open
#       response = self._open(req, data)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 534, in _open
#       result = self._call_chain(self.handle_open, protocol, protocol +
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 494, in _call_chain
#       result = func(*args)
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1385, in https_open
#       return self.do_open(http.client.HTTPSConnection, req,
#     File "C:\Users\Tom\AppData\Local\Programs\Python\Python39\lib\urllib\request.py", line 1345, in do_open
#       raise URLError(err)
#   urllib.error.URLError: <urlopen error EOF occurred in violation of protocol (_ssl.c:1122)>
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/c2/c1/199b4df5ce95fffe1574bb14ca7f1af7e89f944ba96cd91a690266fdd46b/ibm_db-2.0.5.1.tar.gz#sha256=3ba63e9bd616fdb81408016e95155ba5253e12fc991943066f1f0e866b1984da (from https://pypi.org/simple/ibm-db/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: No .egg-info directory found in C:\Users\Tom\AppData\Local\Temp\pip-pip-egg-info-_5g9nxcq
# WARNING: Ignoring invalid distribution -ip (c:\users\tom\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tom\appdata\local\programs\python\python39\lib\site-packages)
# Requirement already satisfied: ipython-sql in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (0.4.0)
# Requirement already satisfied: six in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython>=1.0 in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from ipython-sql) (7.27.0)
# Requirement already satisfied: sqlparse in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from ipython-sql) (0.4.2)
# Requirement already satisfied: prettytable<1 in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from ipython-sql) (1.3.9)
# Requirement already satisfied: matplotlib-inline in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from ipython>=1.0->ipython-sql) (0.1.3)
# Requirement already satisfied: pygments in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from ipython>=1.0->ipython-sql) (2.10.0)
# Requirement already satisfied: backcall in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from ipython>=1.0->ipython-sql) (3.0.20)
# Requirement already satisfied: colorama in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from ipython>=1.0->ipython-sql) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from ipython>=1.0->ipython-sql) (0.18.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from ipython>=1.0->ipython-sql) (5.1.0)
# Requirement already satisfied: pickleshare in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: decorator in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from ipython>=1.0->ipython-sql) (5.1.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from ipython>=1.0->ipython-sql) (57.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\tom\appdata\local\programs\python\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# WARNING: Ignoring invalid distribution -ip (c:\users\tom\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tom\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tom\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tom\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\tom\appdata\local\programs\python\python39\lib\site-packages)

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# %load_ext sql

# %% [markdown]
# **DB2 magic in case of old UI service credentials.**
#
# In the next cell enter your db2 connection string. Recall you created Service Credentials for your Db2 instance before. From the **uri** field of your Db2 service credentials copy everything after db2:// (except the double quote at the end) and paste it in the cell below after ibm_db_sa://
#
# <img src ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_edX/images/URI.jpg">
#
# in the following format
#
# **%sql ibm_db_sa://my-username:my-password\@my-hostname:my-port/my-db-name**
#
# **DB2 magic in case of new UI service credentials.**
#
# <img src ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/servicecredentials.png" width=600>
#
# *   Use the following format.
#
# *   Add security=SSL at the end
#
# **%sql ibm_db_sa://my-username:my-password\@my-hostname:my-port/my-db-name?security=SSL**

# %%
# %sql ibm_db_sa://mmm93649:0Kowf8sr6n67YM6R@55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31929/bludb?security=SSL
# Out:
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
# Can't load plugin: sqlalchemy.dialects:ibm_db_sa
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# ### Task 1
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
SELECT LAUNCH_SITE FROME space

# %% [markdown]
# ### Task 2
#
# ##### Display 5 records where launch sites begin with the string 'KSC'

# %%
SELECT * FROM space WHERE LAUNCH_SITE LIKE 'KSC%'

# %% [markdown]
# ### Task 3
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
SELECT SUM(PAYLOAD_MASS__KG_) FROM space

# %% [markdown]
# ### Task 4
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
SELECT AVG(PAYLOAD_MASS_KG_) FROM space WHERE BOOSTER_VERSION = F9 v1.1

# %% [markdown]
# ### Task 5
#
# ##### List the date where the first succesful landing outcome in drone ship was acheived.
#
# *Hint:Use min function*

# %%
SELECT * FROM space WHERE LANDING_OUTCOME = 'Success (ground pad)' ORDER BY DATE

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in ground pad  and have payload mass greater than 4000 but less than 6000

# %%
SELECT BOOSTER_VERSION FROM space WHERE LANDING_OUTCOME = 'Success (ground pad)' AND PAYLOAD_MASS__KG_ BETWEEN 4000 AND 6000

# %% [markdown]
# ### Task 7
#
# ##### List the total number of successful and failure mission outcomes

# %%
SELECT COUNT(MISSION_OUTCOME) FROM space

# %% [markdown]
# ### Task 8
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %%
SELECT BOOSTER_VERSION, PAYLOAD_MASS__KG_ FROM space ORDER BY PAYLOAD_MASS__KG_ DESC

# %% [markdown]
# ### Task 9
#
# ##### List the records which will display the month names, succesful landing_outcomes in ground pad ,booster versions, launch_site for the months in year 2017

# %%
SELECT DATE, LANDING_OUTCOME, BOOSTER_VERSION, LAUNCH SITE FROM space WHERE LANDING_OUTCOME = 'Success (ground pad)' AND YEAR(DATE)='2017'

# %% [markdown]
# ### Task 10
#
# ##### Rank the  count of  successful landing_outcomes between the date 2010-06-04 and 2017-03-20 in descending order.

# %%
SELECT * FROM space WHERE LANDING_OTUCOME LIKE 'Success%' AND DATE BETWEEN 2010-06-04 AND LAST_DAY(2017-03-20)

# %% [markdown]
# ### Reference Links
#
# *   <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%203/LAB-String_Patterns_Sorting_Grouping.md.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *   <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01">Hands-on Lab: Built-in functions</a>
#
# *   <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *   <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# ## Change log
#
# | Date       | Version | Changed by    | Change Description        |
# | ---------- | ------- | ------------- | ------------------------- |
# | 2021-10-12 | 0.4     | Lakshmi Holla | Changed markdown          |
# | 2021-08-24 | 0.3     | Lakshmi Holla | Added library update      |
# | 2021-07-09 | 0.2     | Lakshmi Holla | Changes made in magic sql |
# | 2021-05-20 | 0.1     | Lakshmi Holla | Created Initial Version   |

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
